# %% [markdown]
# <a href="https://colab.research.google.com/github/aparnatd01/DS/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

x = [1, 2, 6, 18]
y = [3, 10, 12, 20]

plt.plot(x, y, 'r:')
plt.scatter(x, y, color='green')

plt.show()

# %%
import matplotlib.pyplot as plt
year = [2001, 2002, 2003, 2004, 2005, 2006, 2007]
value = [24000, 22500, 19700, 14500, 10000, 5800, 3000]
plt.figure(figsize=(8,6))
plt.plot(year, value,linestyle="-.",color="red",linewidth=1.2)
plt.plot(year, value,color="green",marker="*",linestyle='none',markersize=20)
plt.title("Value of Car")
plt.xlabel("Year")
plt.ylabel("Value")
plt.grid(True)

plt.show()

# %%
import matplotlib.pyplot as plt
months = ["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct",
          "Nov","Dec"]
affordable = [173,153,195,147,120,144,148,109,174,130,172,131]
luxury = [189,189,105,112,173,109,151,197,174,145,177,161]
super_luxury = [185,185,126,134,196,153,112,133,200,145,167,110]
plt.scatter(months, affordable, color="pink", label="Affordable")
plt.scatter(months, luxury, color="yellow", label="Luxury")
plt.scatter(months, super_luxury, color="blue", label="Super Luxury")
plt.title("Sales Data")
plt.xlabel("Months of Year", fontsize=18)
plt.ylabel("Sales of Segments")
plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("/content/iris.csv")

# %%
#a-----
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("/content/iris.csv")
print(df.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
#b----
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("/content/iris.csv")
plt.scatter(df["sepal_length"], df["sepal_width"])
plt.xlabel("Sepal Length")
plt.ylabel("Sepal Width")
plt.show()

# %%
#c----
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("/content/iris.csv")
colors = {"setosa":"red","versicolor":"green","virginica":"blue"}
for flower in colors:
    data = df[df["species"] == flower]
    plt.scatter(data["sepal_length"], data["sepal_width"],
                color=colors[flower], label=flower)
plt.legend()
plt.show()

# %%
#d---
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("/content/iris.csv")
plt.plot(df["sepal_length"], df["sepal_width"])
plt.xlabel("Sepal Length")
plt.ylabel("Sepal Width")
plt.show()

# %%
#e---
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("/content/iris.csv")
plt.hist(df["sepal_length"])
plt.xlabel("Sepal Length")
plt.show()

# %%
#f---
import pandas as pd
import matplotlib.pyplot as pl
df = pd.read_csv("/content/iris.csv")
data = df.groupby("species")["sepal_length"].sum()
plt.bar(data.index, data.values)
plt.show()

# %%
#g---
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("/content/iris.csv")
df.boxplot(column="sepal_length", by="species")
plt.show()

# %%
#h---
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("/content/iris.csv")
count = df["species"].value_counts()
plt.pie(count, labels=count.index, autopct="%1.1f%%")
plt.show()

# %%
#i---
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("/content/iris.csv")
colors = {"setosa":"red","versicolor":"green","virginica":"blue"}
for flower in colors:
    data = df[df["species"] == flower]
    plt.scatter(data["petal_length"], data["petal_width"],
                color=colors[flower], label=flower)
plt.legend()
plt.show()

# %%
#j---
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("/content/iris.csv")
plt.subplot(2,2,1)
plt.hist(df["sepal_length"])
plt.subplot(2,2,2)
plt.hist(df["sepal_width"])
plt.subplot(2,2,3)
plt.hist(df["petal_length"])
plt.subplot(2,2,4)
plt.hist(df["petal_width"])
plt.tight_layout()
plt.show()

# %%
#k-----
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("/content/iris.csv")
avg = df.groupby("species")[["sepal_length","sepal_width"]].mean()
avg.plot(kind="bar")
plt.show()

# %%
#l--
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("/content/iris.csv")
plt.scatter(df["petal_length"],
            df["petal_width"],
            s=df["sepal_length"]*20)
plt.xlabel("Petal Length")
plt.ylabel("Petal Width")
plt.show()

# %%
#5.1----------------
import pandas as pd

s = pd.Series([1, 3, 5, 6, 8])

print("Series:")
print(s)
# Out:
# Series:
# 0    1
# 1    3
# 2    5
# 3    6
# 4    8
# dtype: int64

# %%
#5.2----------
data = {
    "Country": ["Brazil", "Russia", "India", "China", "South Africa"],
    "Capital": ["Brasilia", "Moscow", "New Delhi", "Beijing", "Pretoria"],
    "Area": [8515767, 17098242, 3287263, 9596961, 1221037],
    "Population": [214, 144, 1428, 1412, 60]
}

df = pd.DataFrame(data, index=["BR", "RU", "IN", "CH", "SA"])

print("\nBRICS DataFrame:")
print(df)
# Out:
# BRICS DataFrame:
#          Country    Capital      Area  Population
# BR        Brazil   Brasilia   8515767         214
# RU        Russia     Moscow  17098242         144
# IN         India  New Delhi   3287263        1428
# CH         China    Beijing   9596961        1412
# SA  South Africa   Pretoria   1221037          60

# %%
#5.3--------
cars = pd.read_csv("/content/cars1.csv")
print("\nComplete Dataset:")
print(cars)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_4476/4019430190.py in <cell line: 0>()
#       1 #5.3--------
# ----> 2 cars = pd.read_csv("/content/cars1.csv")
#       3 print("\nComplete Dataset:")
#       4 print(cars)
#
# ...

# %%
#3.a---------------
cars = pd.read_csv("/content/cars1.csv")
print("\nFirst Four Records:")
print(cars.head(4))

# %%
#3.b--------------
cars = pd.read_csv("/content/cars1.csv")
print("\nFifth and Sixth Records:")
print(cars.iloc[4:6])

# %%
#3.c----------
cars = pd.read_csv("/content/cars1.csv")
print("\nThird Row:")
print(cars.iloc[2])

# %%
#4---------------
import pandas as pd
data = {
    "Name": ["Anu", "Rahul", "Meera", "Arun"],
    "Gender": ["Female", "Male", "Female", "Male"],
    "Age": [20, 22, 21, 23]
}
df = pd.DataFrame(data)
print("DataFrame:")
print(df)

# %%
#4.a------------
import pandas as pd
data = {
    "Name": ["Anu", "Rahul", "Meera", "Arun"],
    "Gender": ["Female", "Male", "Female", "Male"],
    "Age": [20, 22, 21, 23]
}
df = pd.DataFrame(data)
print("\nFirst two rows:")
print(df[:2])

# %%
#4.b---------------
import pandas as pd
data = {
    "Name": ["Anu", "Rahul", "Meera", "Arun"],
    "Gender": ["Female", "Male", "Female", "Male"],
    "Age": [20, 22, 21, 23]
}
df = pd.DataFrame(data)
print("\nThird row onwards:")
print(df[2:])

# %%
#5--------------
import pandas as pd
import numpy as np

s = pd.Series(np.random.rand(4))

print("Complete Series:")
print(s)

print("\nValues:")
print(s.values)

print("\nFirst Two Elements:")
print(s.head(2))

print("\nLast Three Elements:")
print(s.tail(3))

# %%
#6-----------
import pandas as pd

data = {
    'Name': ['Anu', 'Ammu', 'Arun'],
    'Age': [20, 21, 22],
    'Rating': [4.5, 4.0, 4.8]
}

df = pd.DataFrame(data)

print("DataFrame:")
print(df)

# %%
#6.a----------
import pandas as pd
data = {
    "Name": ["Anu", "Ammu", "Arun"],
    "Age": [20, 21, 22],
    "Rating": [4.5, 4.0, 4.8]
}
df = pd.DataFrame(data)
print("\nTranspose:")
print(df.T)

# %%
#6.b-------------

import pandas as pd
data = {
  "Name": ["Anu", "Ammu", "Arun"],
    "Age": [20, 21, 22],
    "Rating": [4.5, 4.0, 4.8]
}
df = pd.DataFrame(data)
print("\nAxes:")
print(df.axes)

# %%
#6.c--------------
import pandas as pd
data = {
  "Name": ["Anu", "Ammu", "Arun"],
    "Age": [20, 21, 22],
    "Rating": [4.5, 4.0, 4.8]
}
df = pd.DataFrame(data)
print("\nData Types:")
print(df.dtypes)

# %%
#6.d-------------
import pandas as pd
data = {
  "Name": ["Anu", "Ammu", "Arun"],
    "Age": [20, 21, 22],
    "Rating": [4.5, 4.0, 4.8]
}
df = pd.DataFrame(data)
print("\nIs DataFrame Empty?")
print(df.empty)

# %%
#6.e-------------
import pandas as pd
data = {
  "Name": ["Anu", "Ammu", "Arun"],
    "Age": [20, 21, 22],
    "Rating": [4.5, 4.0, 4.8]
}
df = pd.DataFrame(data)
print("\nNumber of Dimensions:")
print(df.ndim)

# %%
#6.f-----------
import pandas as pd
data = {
  "Name": ["Anu", "Ammu", "Arun"],
    "Age": [20, 21, 22],
    "Rating": [4.5, 4.0, 4.8]
}
df = pd.DataFrame(data)
print("\nShape:")
print(df.shape)

# %%
#6.g---------
import pandas as pd
data = {
  "Name": ["Anu", "Ammu", "Arun"],
    "Age": [20, 21, 22],
    "Rating": [4.5, 4.0, 4.8]
}
df = pd.DataFrame(data)
print("\nTotal Number of Elements:")
print(df.size)

# %%
#6.h--------

import pandas as pd
data = {
  "Name": ["Anu", "Ammu", "Arun"],
    "Age": [20, 21, 22],
    "Rating": [4.5, 4.0, 4.8]
}
df = pd.DataFrame(data)
print("\nValues:")
print(df.values)

# %%
#6.i-----------
import pandas as pd
data = {
  "Name": ["Anu", "Ammu", "Arun"],
    "Age": [20, 21, 22],
    "Rating": [4.5, 4.0, 4.8]
}
df = pd.DataFrame(data)
print("\nMissing Values:")
print(df.isnull().sum())

# %%
import pandas as pd

df = pd.read_csv("/content/cars1.csv")

print("Complete Dataset:")
print(df)

print("\nFirst Four Records:")
print(df.head(4))

print("\nFifth and Sixth Records:")
print(df.iloc[4:6])

print("\nThird Row:")
print(df.iloc[2])

# %%
import pandas as pd

data = {
    'Name': ['Anu', 'Ammu', 'Arun', 'Rahul'],
    'Gender': ["Female", "Female", "Male", "Male"],
    'Age': [20, 21, 22, 23]
}
datas=pd.DataFrame(data)
print("\n student DataFrame")
print(datas)

df = pd.DataFrame(data)

print("\nFirst Two Rows:")
print(df[:2])

print("\nThird Row Onwards:")
print(df[2:])

# %%
import pandas as pd
import numpy as np

s = pd.Series(np.random.rand(4))

print("Complete Series:")
print(s)

print("\nValues:")
print(s.values)

print("\nFirst Two Elements:")
print(s.head(2))

print("\nLast Three Elements:")
print(s.tail(3))

# %%
import pandas as pd

data = {
    'Name': ['Anu', 'Ammu', 'Arun'],
    'Age': [20, 21, 22],
    'Rating': [4.5, 4.0, 4.8]
}

df = pd.DataFrame(data)

print("DataFrame:")
print(df)

print("\nTranspose:")
print(df.T)

print("\nAxes:")
print(df.axes)

print("\nData Types:")
print(df.dtypes)

print("\nIs Empty:")
print(df.empty)

print("\nNumber of Dimensions:")
print(df.ndim)

print("\nShape:")
print(df.shape)

print("\nSize:")
print(df.size)

print("\nValues:")
print(df.values)

print("\nMissing Values:")
print(df.isnull().sum())

# %%
#6-------------------
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

url = "/content/Iris - Iris.csv"
df = pd.read_csv(url)

print(df.head())
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
X = df.drop("species", axis=1)
y = df["species"]

print("Features:")
print(X.head())

print("\nTarget:")
print(y.head())
# Out:
# Features:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2
#
# Target:
# 0    setosa
# 1    setosa
# 2    setosa
# 3    setosa
# 4    setosa
# Name: species, dtype: object

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

print("Training data:", X_train.shape)
print("Testing data:", X_test.shape)
# Out:
# Training data: (120, 4)
# Testing data: (30, 4)

# %%
scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

print("Feature scaling completed.")
# Out:
# Feature scaling completed.

# %%
knn = KNeighborsClassifier(n_neighbors=5)

knn.fit(X_train, y_train)

print("k-NN model trained successfully.")
# Out:
# k-NN model trained successfully.

# %%
y_pred = knn.predict(X_test)

print("Predicted classes:")
print(y_pred)
# Out:
# Predicted classes:
# ['setosa' 'virginica' 'versicolor' 'versicolor' 'setosa' 'versicolor'
#  'setosa' 'setosa' 'virginica' 'versicolor' 'virginica' 'virginica'
#  'virginica' 'versicolor' 'setosa' 'setosa' 'setosa' 'versicolor'
#  'versicolor' 'versicolor' 'setosa' 'virginica' 'versicolor' 'versicolor'
#  'virginica' 'versicolor' 'versicolor' 'setosa' 'virginica' 'setosa']

# %%
cm = confusion_matrix(y_test, y_pred)

print("Confusion Matrix:")
print(cm)
# Out:
# Confusion Matrix:
# [[10  0  0]
#  [10  0  0]
#  [10  0  0]]

# %%
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        10
#   versicolor       0.83      1.00      0.91        10
#    virginica       1.00      0.80      0.89        10
#
#     accuracy                           0.93        30
#    macro avg       0.94      0.93      0.93        30
# weighted avg       0.94      0.93      0.93        30

# %%
accuracy = accuracy_score(y_test, y_pred)

print("Accuracy:", accuracy)
print("Accuracy (%):", accuracy * 100)
# Out:
# Accuracy: 0.3333333333333333
# Accuracy (%): 33.33333333333333
